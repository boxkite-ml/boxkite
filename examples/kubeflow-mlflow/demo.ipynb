# %%
# !pip install mlflow sklearn boxkite dataclasses boto3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mlflow
#   Downloading mlflow-1.15.0-py3-none-any.whl (14.2 MB)
#      |████████████████████████████████| 14.2 MB 4.1 MB/s eta 0:00:01
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Collecting boxkite
#   Downloading boxkite-0.0.2-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 15.2 MB/s eta 0:00:01
# Collecting dataclasses
#   Downloading dataclasses-0.8-py3-none-any.whl (19 kB)
# Collecting boto3
#   Downloading boto3-1.17.47-py2.py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 12.0 MB/s eta 0:00:01
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.6/dist-packages (from mlflow) (0.3)
# Collecting alembic<=1.4.1
#   Downloading alembic-1.4.1.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 17.5 MB/s eta 0:00:01
# Collecting Flask
#   Downloading Flask-1.1.2-py2.py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 7.6 MB/s  eta 0:00:01
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from mlflow) (2019.3)
# Collecting prometheus-flask-exporter
#   Downloading prometheus_flask_exporter-0.18.1.tar.gz (21 kB)
# Collecting querystring-parser
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Collecting sqlparse>=0.3.1
#   Downloading sqlparse-0.4.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 3.4 MB/s  eta 0:00:01
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.6/dist-packages (from mlflow) (1.2.2)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.6/dist-packages (from mlflow) (3.11.2)
# Collecting gitpython>=2.1.0
#   Downloading GitPython-3.1.14-py3-none-any.whl (159 kB)
#      |████████████████████████████████| 159 kB 19.2 MB/s eta 0:00:01
# Collecting sqlalchemy
#   Downloading SQLAlchemy-1.4.6-cp36-cp36m-manylinux2014_x86_64.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 20.0 MB/s eta 0:00:01
# Collecting gunicorn; platform_system != "Windows"
#   Downloading gunicorn-20.1.0.tar.gz (370 kB)
#      |████████████████████████████████| 370 kB 22.8 MB/s eta 0:00:01
# Collecting click>=7.0
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 2.2 MB/s  eta 0:00:01
# Requirement already satisfied: docker>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from mlflow) (4.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from mlflow) (1.18.1)
# Collecting pandas
#   Downloading pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 23.7 MB/s eta 0:00:01
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from mlflow) (5.3)
# Requirement already satisfied: requests>=2.17.3 in /usr/local/lib/python3.6/dist-packages (from mlflow) (2.22.0)
# Collecting databricks-cli>=0.8.7
#   Downloading databricks-cli-0.14.3.tar.gz (54 kB)
#      |████████████████████████████████| 54 kB 8.2 MB/s  eta 0:00:01
# Collecting scikit-learn
#   Downloading scikit_learn-0.24.1-cp36-cp36m-manylinux2010_x86_64.whl (22.2 MB)
#      |████████████████████████████████| 22.2 MB 28.3 MB/s eta 0:00:01
# Collecting fluent-logger==0.9.6
#   Downloading fluent_logger-0.9.6-py2.py3-none-any.whl (12 kB)
# Collecting prometheus-client==0.9
#   Downloading prometheus_client-0.9.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 7.6 MB/s  eta 0:00:01
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading s3transfer-0.3.6-py2.py3-none-any.whl (73 kB)
#      |████████████████████████████████| 73 kB 3.8 MB/s  eta 0:00:01
# Collecting botocore<1.21.0,>=1.20.47
#   Downloading botocore-1.20.47-py2.py3-none-any.whl (7.4 MB)
#      |████████████████████████████████| 7.4 MB 29.4 MB/s eta 0:00:01
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting Mako
#   Downloading Mako-1.1.4-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 11.1 MB/s eta 0:00:01
# Collecting python-editor>=0.3
#   Downloading python_editor-1.0.4-py3-none-any.whl (4.9 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from alembic<=1.4.1->mlflow) (2.8.1)
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.6/dist-packages (from Flask->mlflow) (2.11.0)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.6/dist-packages (from Flask->mlflow) (0.16.1)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from querystring-parser->mlflow) (1.11.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.0->mlflow) (45.1.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.7-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 5.5 MB/s  eta 0:00:01
# Collecting greenlet!=0.4.17; python_version >= "3"
#   Downloading greenlet-1.0.0-cp36-cp36m-manylinux2010_x86_64.whl (156 kB)
#      |████████████████████████████████| 156 kB 22.0 MB/s eta 0:00:01   |████▏                           | 20 kB 8.6 MB/s eta 0:00:01
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from sqlalchemy->mlflow) (1.4.0)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.6/dist-packages (from docker>=4.0.0->mlflow) (0.57.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.17.3->mlflow) (2.6)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.17.3->mlflow) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.17.3->mlflow) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.17.3->mlflow) (3.0.4)
# Collecting tabulate>=0.7.7
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Collecting joblib>=0.11
#   Downloading joblib-1.0.1-py3-none-any.whl (303 kB)
#      |████████████████████████████████| 303 kB 31.0 MB/s eta 0:00:01
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.4.1)
# Collecting msgpack<1.0.0
#   Downloading msgpack-0.6.2-cp36-cp36m-manylinux1_x86_64.whl (249 kB)
#      |████████████████████████████████| 249 kB 20.6 MB/s eta 0:00:01
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from Mako->alembic<=1.4.1->mlflow) (1.1.1)
# Collecting smmap<5,>=3.0.1
#   Downloading smmap-4.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->sqlalchemy->mlflow) (2.1.0)
# Building wheels for collected packages: sklearn, alembic, prometheus-flask-exporter, gunicorn, databricks-cli
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=2397 sha256=99bd6e6cd1dfda66de8ae00ff637b262eff759f278c2276030d95f2612968514
#   Stored in directory: /home/jovyan/.cache/pip/wheels/23/9d/42/5ec745cbbb17517000a53cecc49d6a865450d1f5cb16dc8a9c
#   Building wheel for alembic (setup.py) ... done
#   Created wheel for alembic: filename=alembic-1.4.1-py2.py3-none-any.whl size=160574 sha256=2f12e45ec609d2e5d1b1d58f59a44e0f8eb01539982b7725aedca040b94ef9ed
#   Stored in directory: /home/jovyan/.cache/pip/wheels/e9/7b/aa/e18c983d8236b141f85838ba0f8e4e4ae9bcf7f1e00ff726ec
#   Building wheel for prometheus-flask-exporter (setup.py) ... done
#   Created wheel for prometheus-flask-exporter: filename=prometheus_flask_exporter-0.18.1-py3-none-any.whl size=22573 sha256=457207fe47bc6f63b7e0d103c57daf097eb54af4954c556aa80edf3af5a24995
#   Stored in directory: /home/jovyan/.cache/pip/wheels/fe/70/a9/22af6c68f513e58533fb7fd649f4cc5e2a27c24422a41a1bfa
#   Building wheel for gunicorn (setup.py) ... done
#   Created wheel for gunicorn: filename=gunicorn-20.1.0-py3-none-any.whl size=81013 sha256=972abce57dd22ee729ce23db43bfa4b24aa2e89c7d5b4d45dd829f6fcc2b6cc2
#   Stored in directory: /home/jovyan/.cache/pip/wheels/9a/86/37/cad4bc71746b420e17c4eb0f5c41cf7b5e653c1fdbda27d198
#   Building wheel for databricks-cli (setup.py) ... done
#   Created wheel for databricks-cli: filename=databricks_cli-0.14.3-py3-none-any.whl size=102697 sha256=29bbbb498cdc612b9c4eca62755f2da544f5077b5d788be9a7c3f8061b65dbea
#   Stored in directory: /home/jovyan/.cache/pip/wheels/ce/88/95/bd32d0e2dc0cf30e55574faab3118df2bb9ebebc60978c147b
# Successfully built sklearn alembic prometheus-flask-exporter gunicorn databricks-cli
# ERROR: fairing 0.5 has requirement tornado<6.0.0,>=5.1.1, but you'll have tornado 6.0.3 which is incompatible.
# ERROR: boxkite 0.0.2 has requirement numpy==1.19.4, but you'll have numpy 1.18.1 which is incompatible.
# Installing collected packages: greenlet, sqlalchemy, Mako, python-editor, alembic, click, itsdangerous, Flask, prometheus-client, prometheus-flask-exporter, querystring-parser, sqlparse, smmap, gitdb, gitpython, gunicorn, pandas, tabulate, databricks-cli, mlflow, joblib, threadpoolctl, scikit-learn, sklearn, msgpack, fluent-logger, boxkite, dataclasses, jmespath, botocore, s3transfer, boto3
#   WARNING: The script mako-render is installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script alembic is installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script flask is installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script sqlformat is installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script gunicorn is installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tabulate is installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts databricks and dbfs are installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script mlflow is installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed Flask-1.1.2 Mako-1.1.4 alembic-1.4.1 boto3-1.17.47 botocore-1.20.47 boxkite-0.0.2 click-7.1.2 databricks-cli-0.14.3 dataclasses-0.8 fluent-logger-0.9.6 gitdb-4.0.7 gitpython-3.1.14 greenlet-1.0.0 gunicorn-20.1.0 itsdangerous-1.1.0 jmespath-0.10.0 joblib-1.0.1 mlflow-1.15.0 msgpack-0.6.2 pandas-1.1.5 prometheus-client-0.9.0 prometheus-flask-exporter-0.18.1 python-editor-1.0.4 querystring-parser-1.2.4 s3transfer-0.3.6 scikit-learn-0.24.1 sklearn-0.0 smmap-4.0.0 sqlalchemy-1.4.6 sqlparse-0.4.1 tabulate-0.8.9 threadpoolctl-2.1.0
# WARNING: You are using pip version 20.0.2; however, version 21.0.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import pickle

from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from boxkite.monitoring.service import ModelMonitoringService

import mlflow
mlflow.sklearn.autolog()

# %%
with mlflow.start_run() as run:

    bunch = load_diabetes()
    X_train, X_test, Y_train, Y_test = train_test_split(
        bunch.data, bunch.target
    )
    model = LinearRegression()
    model.fit(X_train, Y_train)

    print("Score: %.2f" % model.score(X_test, Y_test))
    with open("./model.pkl", "wb") as f:
        pickle.dump(model, f)

    features = zip(*[bunch.feature_names, X_train.T])
    # features = [("age", [33, 23, 54, ...]), ("sex", [0, 1, 0]), ...]
    ModelMonitoringService.export_text(
        features=features, path="./histogram.prom",
    )
    mlflow.log_artifact("./histogram.prom")
# Out:
# Score: 0.54

# %%
import mlflow
# Get this from MLflow UI
logged_model = 's3://mlflow-artifacts/0/134f7343adf342b68046efe7e4f389c3/artifacts/model'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)

# Predict on a Pandas DataFrame.
import pandas as pd
loaded_model.predict(pd.DataFrame(X_test))
# Out:
# array([123.04994884, 227.07801219,  90.28349888, 136.99993405,
#         64.42123992, 102.24358733, 280.7955021 , 197.65219032,
#        224.75650891, 280.10278244,  77.70495443, 166.78218112,
#        103.52713245, 167.09631954, 153.35756698, 240.63926662,
#        136.04693198, 169.47984237, 124.5833244 , 279.29183373,
#        112.57086981,  94.20578999, 239.19823543, 125.69567902,
#        186.09269719, 237.64952599, 146.44545148, 162.28794204,
#         68.53966597, 137.70198155, 201.14109399, 121.35056669,
#        108.24311489, 221.89775819, 141.12743574,  34.47048126,
#        219.56452278,  70.59666586, 224.97612627, 140.26183757,
#         68.31699084, 236.37096734, 165.76641029,  75.07197914,
#        212.04752004, 189.80484158, 116.79844654, 142.79529704,
#        150.32015566, 117.64560673, 102.66243265, 195.11165152,
#         75.06959993, 157.77660561, 141.0845715 , 190.15881287,
#        156.08816333,  78.21346932, 187.04922109, 111.54161513,
#         96.48270088,  88.09327992, 148.15255386, 159.31670235,
#        172.02536881, 111.35387253, 172.87303145, 101.18020742,
#        124.84141773, 152.65154819, 154.26792843,  77.64031804,
#         59.2155646 , 235.10231669,  73.16085306,  81.77701417,
#        127.51345676,  82.46278159, 189.13166733,  80.02903924,
#        134.39784872, 184.88326853, 104.74716087, 135.94730297,
#         99.23555983,  88.75361201, 219.32168594, 109.59257337,
#        167.49558197,  85.95751059, 114.48508898, 191.76460109,
#        151.43829318, 275.86393136, 241.64392691, 134.65287617,
#         99.51679907, 134.41986885,  90.51553214, 162.46797531,
#         87.20666897, 171.729197  , 194.31528217, 222.62581029,
#        157.70723039, 190.56103076, 207.44239558, 121.24752807,
#         63.71290108, 213.94793718, 255.48606207])

# %%
type(loaded_model._model_impl)
# Out:
# sklearn.linear_model._base.LinearRegression

# %% [markdown]
# ## What to do next
#
# Port https://github.com/basisai/boxkite/blob/master/examples/grafana-prometheus/app/serve_completed.py
# to a container that can speak to MLflow.
#
# Have it fetch a model by ID along with its histogram and serve it while exposing Prom metrics.
#
# Have Prom + Grafana in the cluster serve an appropriate dashboard (prom dashboard auto setup with provisioning or Grafana terraform provider).
